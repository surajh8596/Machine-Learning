# %% [markdown]
# **Incresing the performance of model using "Gradient Descent" & "Trasforming The Model"**

# %%
import numpy as np

# %%
#from os import X_OK
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

m_curr=b_curr=0
lr = 0.01 # Learning rate
n = len(x)

steps = 1000
for i in range(steps):
    y_pred = m_curr*x + b_curr
    loss = (1/n) * sum([val**2 for val in (y-y_pred)])
    md = -(2/n) * sum(x * (y-y_pred))   # Partial Derivative m wrt loss(mse)
    bd = -(2/n) * sum(y-y_pred)         # Partial Derivative b wrt loss(mse)
    m_curr = m_curr-lr*md
    b_curr = b_curr-lr*bd 
    print("m={}, b={}, loss={}".format(m_curr,b_curr,loss))
# Out:
# m=0.62, b=0.18, loss=89.0
# m=1.0928, b=0.3192, loss=52.25039999999999
# m=1.453232, b=0.42724799999999996, loss=30.831949440000002
# m=1.7278860800000002, b=0.5115091199999999, loss=18.347751350784
# m=1.9370605952000002, b=0.5776057727999999, loss=11.070010749324897
# m=2.096250917888, b=0.6298300216319999, loss=6.826353152519786
# m=2.2172859146547204, b=0.6714583661260799, loss=4.350826141683065
# m=2.309195511463117, b=0.7049920439242751, loss=2.9056952040975976
# m=2.3788729763057748, b=0.7323404723580026, loss=2.0610450731046615
# m=2.431580493177024, b=0.7549612843324961, loss=1.5663423003130599
# m=2.471335107618129, b=0.7739672290552247, loss=1.2755882811903883
# m=2.501203350198827, b=0.7902077780170325, loss=1.1037021437989751
# m=2.523526146474063, b=0.8043314214447622, loss=1.0011028556851886
# m=2.5400905089630834, b=0.8168332242274232, loss=0.9388969341253388
# m=2.55226060353756, b=0.8280911292050898, loss=0.9002465769594267
# ...

# %%
import pandas as pd
d=pd.read_csv('')

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load the training dataset

# %%
bike_data=pd.read_csv('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/daily-bike-share.csv')
bike_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1    1/1/2011       1   0     1        0        6           0
# 1          2    1/2/2011       1   0     1        0        0           0
# 2          3    1/3/2011       1   0     1        0        1           1
# 3          4    1/4/2011       1   0     1        0        2           1
# 4          5    1/5/2011       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  12/27/2012       1   1    12        0        4           1
# 727      728  12/28/2012       1   1    12        0        5           1
# 728      729  12/29/2012       1   1    12        0        6           0
# 729      730  12/30/2012       1   1    12        0        0           0
# 730      731  12/31/2012       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  rentals
# ...

# %% [markdown]
# ### Create new column "Day" of the month from "dteday"

# %%
bike_data['day'] = pd.DatetimeIndex(bike_data['dteday']).day
bike_data.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1        0        6           0
# 1        2  1/2/2011       1   0     1        0        0           0
# 2        3  1/3/2011       1   0     1        0        1           1
# 3        4  1/4/2011       1   0     1        0        2           1
# 4        5  1/5/2011       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  rentals  day
# 0           2  0.344167  0.363625  0.805833   0.160446      331    1
# 1           2  0.363478  0.353739  0.696087   0.248539      131    2
# 2           1  0.196364  0.189405  0.437273   0.248309      120    3
# 3           1  0.200000  0.212122  0.590435   0.160296      108    4
# 4           1  0.226957  0.229270  0.436957   0.186900       82    5

# %% [markdown]
# ### Seperate out numerical & categorical features

# %%
numeric_features = ['temp', 'atemp', 'hum', 'windspeed']
categorical_features = ['season','mnth','holiday','weekday','workingday','weathersit', 'day']

# %% [markdown]
# ### Statistical measures of numerical columns

# %%
bike_data[numeric_features + ['rentals']].describe()
# Out:
#              temp       atemp         hum   windspeed      rentals
# count  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     0.495385    0.474354    0.627894    0.190486   848.176471
# std      0.183051    0.162961    0.142429    0.077498   686.622488
# min      0.059130    0.079070    0.000000    0.022392     2.000000
# 25%      0.337083    0.337842    0.520000    0.134950   315.500000
# 50%      0.498333    0.486733    0.626667    0.180975   713.000000
# 75%      0.655417    0.608602    0.730209    0.233214  1096.000000
# max      0.861667    0.840896    0.972500    0.507463  3410.000000

# %% [markdown]
# ### Separate features and labels
# After separating the dataset, we now have numpy arrays named **X** containing the features, and **y** containing the labels.

# %%
X, y = bike_data[['season','mnth', 'holiday','weekday','workingday','weathersit','temp', 'atemp', 'hum', 'windspeed']].values, bike_data['rentals'].values

# %% [markdown]
# ### Split the data into training & testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 511 rows
# Test Set: 220 rows

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Fit a linear regression model on the training set

# %%
model = LinearRegression().fit(X_train, y_train)
print (model)
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaluate the model using the test data

# %%
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)
print("Training Accuracy", model.score(X_train, y_train))
print("Testing Accuracy", model.score(X_test, y_test))
# Out:
# MSE: 201972.55947035577
# RMSE: 449.4135728595163
# R2: 0.6040454736919193
# Training Accuracy 0.6572018150411183
# Testing Accuracy 0.6040454736919193

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# ### Define preprocessing for numeric columns (scale them)

# %%
numeric_features = [6,7,8,9]
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

# %% [markdown]
# ### Define preprocessing for categorical features (encode them)

# %%
categorical_features = [0,1,2,3,4,5]
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %% [markdown]
# ### Combine preprocessing steps

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# ### Create preprocessing and training pipeline

# %%
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('regressor', LinearRegression())])

# %% [markdown]
# ### fit the pipeline to train a linear regression model on the training set

# %%
model = pipeline.fit(X_train, (y_train))
print (model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   [6, 7, 8, 9]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   [0, 1, 2, 3, 4, 5])])),
#                 ('regressor', LinearRegression())])

# %% [markdown]
# ### Evaluate the model using the test data

# %%
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)
print("Training Accuracy", model.score(X_train, y_train))
print("Tesing Accuracy", model.score(X_test, y_test))
# Out:
# MSE: 174159.78124333423
# RMSE: 417.3245514504679
# R2: 0.6585706797747207
# Training Accuracy 0.7093797296481488
# Tesing Accuracy 0.6585706797747207

# %% [markdown]
# Inference: Accuracy in incresed

# %% [markdown]
# ### Model production (saving model or dump model)

# %%
import joblib

# Save the model as a pickle file
filename = './bike-share.pkl'
joblib.dump(model, filename)
# Out:
# ['./bike-share.pkl']

# %% [markdown]
# ### Use model

# %%
loaded_model = joblib.load(filename)

# %% [markdown]
# ### To know the rental for below values

# %%
X_new = np.array([[1,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869]]).astype('float64')
print ('New sample: {}'.format(list(X_new[0])))
# Out:
# New sample: [1.0, 1.0, 0.0, 3.0, 1.0, 1.0, 0.226957, 0.22927, 0.436957, 0.1869]

# %%
result = loaded_model.predict(X_new)
print('Prediction: {:.0f} rentals'.format(np.round(result[0])))
# Out:
# Prediction: 47 rentals

# %% [markdown]
# ### To know the rental for below values

# %%
X_new = np.array([[0,1,1,0,0,1,0.344167,0.363625,0.805833,0.160446]]).astype('float64')

result = loaded_model.predict(X_new)
print('Prediction: {:.0f} rentals'.format(np.round(result[0])))
# Out:
# Prediction: 868 rentals

# %% [markdown]
# ### Use the model to predict rentals

# %%
X_new = np.array([[0,1,1,0,0,1,0.344167,0.363625,0.805833,0.160446],
                  [0,1,0,1,0,1,0.363478,0.353739,0.696087,0.248539],
                  [0,1,0,2,0,1,0.196364,0.189405,0.437273,0.248309],
                  [0,1,0,3,0,1,0.2,0.212122,0.590435,0.160296],
                  [0,1,0,4,0,1,0.226957,0.22927,0.436957,0.1869]])

results = loaded_model.predict(X_new)
print('5-day rental predictions:')
for prediction in results:
    print(np.round(prediction))
# Out:
# 5-day rental predictions:
# 868.0
# 785.0
# 573.0
# 598.0
# 747.0
